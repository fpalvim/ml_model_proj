# %% [markdown]
# # Proyecto Machine Learning sobre predicción de deficiencia cardiaca

# %% [markdown]
# ![](https://nexxto.com/wp-content/uploads/2021/01/6-tecnologias-para-saude-2021-scaled.jpg)

# %% [markdown]
# ## Introducción

# %% [markdown]
# Las enfermedades del corazón son un problema grave. Detectarlas a tiempo es vital. Este proyecto usa machine learning para predecir si una persona tiene o no problemas cardíacos, buscando una forma más rápida y precisa de ayudar a la gente.

# %% [markdown]
# ## Objetivo

# %% [markdown]
# Este proyecto de machine learning se centra en la predicción de enfermedades cardíacas utilizando exclusivamente datos clínicos. Hemos desarrollado modelos capaces de determinar si un paciente presenta o no riesgo de padecer estas afecciones, basándonos únicamente en información clínica relevante.

# %% [markdown]
# ## Hipótesis

# %% [markdown]
# Se explora la viabilidad de predecir la enfermedad cardíaca a partir de la información contenida en datos clínicos.

# %% [markdown]
# # Preparación y carga de datos

# %% [markdown]
# ## Librerias

# %%
import pandas as pd
import numpy as np
import os
import sys
from pathlib import Path

# %%
# Creando ruta absoluta de la carpeta del proyecto
root_path = Path(os.getcwd()).resolve().parent
sys.path.append(str(root_path))

# %%
# Importación de funciones auxiliares del script AutoImporter
from src.utils.auto_importer import AutoImporter, DataFrameDescriber, CompleteDescribeTable

# %% [markdown]
# ## Carga de datos

# %%
# Cargando los datos del archivo descargado del sitio Kaggle
df = pd.read_csv("../data/raw/heart_attack_prediction_dataset.csv")

# %% [markdown]
# ## Primera exploración

# %%
df
# Out:
#       Edad Sexo TipoDolorTorax  PresionArterialReposo  Colesterol  \
# 0       40    M            ATA                    140         289
# 1       49    F            NAP                    160         180
# 2       37    M            ATA                    130         283
# 3       48    F            ASY                    138         214
# 4       54    M            NAP                    150         195
# ...    ...  ...            ...                    ...         ...
# 1191    42    F            ASY                    159         463
# 1192    30    F            ASY                    173         356
# 1193    34    M             TA                    177         432
# 1194    54    M            NAP                    122         540
# 1195    36    F            NAP                     95         274
#
#       GlucosaEnAyunas ECGReposo  FreqCardiacaMaxima AnginaDeEsfuerzo  \
# 0                   0    Normal                 172                N
# 1                   0    Normal                 156                N
# 2                   0        ST                  98                N
# 3                   0    Normal                 108                Y
# 4                   0    Normal                 122                N
# ...               ...       ...                 ...              ...
# 1191                0        ST                  99                N
# 1192                0    Normal                 186                Y
# 1193                1       LVH                 136                N
# 1194                0        ST                 113                N
# 1195                0        ST                 178                Y
#
#       DescensoST PendienteST  EnfermedadCardiaca
# 0            0.0          Up                   0
# 1            1.0        Flat                   1
# 2            0.0          Up                   0
# 3            1.5        Flat                   1
# 4            0.0          Up                   0
# ...          ...         ...                 ...
# 1191         0.3        Down                   1
# 1192         3.7        Down                   1
# 1193         5.2          Up                   0
# 1194         0.5        Down                   1
# 1195         4.1        Flat                   1
#
# [1196 rows x 12 columns]

# %%
# Creando la copia del conjunto de datos para trabajar sobre la copia y mantener los datos originales intactos para futuras consultas si es necesario

data = df.copy()

# %%
# Instanciando funciones importadas del script para hacer la primer análisis de los datos

primera_inspeccion = AutoImporter(data)
descripcion_data = DataFrameDescriber(data)
tabla_completa = CompleteDescribeTable(data)

# %%
primera_inspeccion.inspeccion_inicial()
# Out:
# === TAMAÑO Y ESTRUCTURA DE LOS DATOS ===
# Número total de registros: 1196
# Número de columnas: 12
# Uso de memoria: 112.25 KB
#
#
# === TIPOS DE DATOS Y NOMBRES DE COLUMNAS ===
# Edad                       int64
# Sexo                      object
# TipoDolorTorax            object
# PresionArterialReposo      int64
# Colesterol                 int64
# GlucosaEnAyunas            int64
# ECGReposo                 object
# FreqCardiacaMaxima         int64
# AnginaDeEsfuerzo          object
# DescensoST               float64
# PendienteST               object
# EnfermedadCardiaca         int64
# dtype: object
#
#
# Información detallada del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1196 entries, 0 to 1195
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Edad                   1196 non-null   int64
#  1   Sexo                   1196 non-null   object
#  2   TipoDolorTorax         1196 non-null   object
#  3   PresionArterialReposo  1196 non-null   int64
#  4   Colesterol             1196 non-null   int64
#  5   GlucosaEnAyunas        1196 non-null   int64
#  6   ECGReposo              1196 non-null   object
#  7   FreqCardiacaMaxima     1196 non-null   int64
#  8   AnginaDeEsfuerzo       1196 non-null   object
#  9   DescensoST             1196 non-null   float64
#  10  PendienteST            1196 non-null   object
#  11  EnfermedadCardiaca     1196 non-null   int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 112.3+ KB
# None
#
#
# === IDENTIFICACIÓN DE PROBLEMAS INICIALES ===
# Número de filas duplicadas: 0
#
# Valores nulos por columna:
# Edad                     0
# Sexo                     0
# TipoDolorTorax           0
# PresionArterialReposo    0
# Colesterol               0
# GlucosaEnAyunas          0
# ECGReposo                0
# FreqCardiacaMaxima       0
# AnginaDeEsfuerzo         0
# DescensoST               0
# PendienteST              0
# EnfermedadCardiaca       0
# dtype: int64
#
# Valores nulos relativos por columna:
# Edad                     0.0
# Sexo                     0.0
# TipoDolorTorax           0.0
# PresionArterialReposo    0.0
# Colesterol               0.0
# GlucosaEnAyunas          0.0
# ECGReposo                0.0
# FreqCardiacaMaxima       0.0
# AnginaDeEsfuerzo         0.0
# DescensoST               0.0
# PendienteST              0.0
# EnfermedadCardiaca       0.0
# dtype: float64 2
#
# Primeras filas del dataset:
#    Edad Sexo TipoDolorTorax  PresionArterialReposo  Colesterol  \
# 0    40    M            ATA                    140         289
# 1    49    F            NAP                    160         180
# 2    37    M            ATA                    130         283
# 3    48    F            ASY                    138         214
# 4    54    M            NAP                    150         195
#
#    GlucosaEnAyunas ECGReposo  FreqCardiacaMaxima AnginaDeEsfuerzo  DescensoST  \
# 0                0    Normal                 172                N         0.0
# 1                0    Normal                 156                N         1.0
# 2                0        ST                  98                N         0.0
# 3                0    Normal                 108                Y         1.5
# 4                0    Normal                 122                N         0.0
#
#   PendienteST  EnfermedadCardiaca
# 0          Up                   0
# 1        Flat                   1
# 2          Up                   0
# 3        Flat                   1
# 4          Up                   0

# %%
descripcion_data.describe_numerico()
# Out:
#               Edad  PresionArterialReposo   Colesterol  GlucosaEnAyunas  \
# count  1196.000000            1196.000000  1196.000000      1196.000000
# mean     53.341137             134.709030   230.504181         0.229097
# std      10.776964              22.492932   127.480572         0.420428
# min      28.000000               0.000000     0.000000         0.000000
# 25%      46.000000             120.000000   182.750000         0.000000
# 50%      54.000000             130.000000   233.000000         0.000000
# 75%      61.000000             146.250000   291.000000         0.000000
# max      77.000000             200.000000   603.000000         1.000000
#
#        FreqCardiacaMaxima   DescensoST  EnfermedadCardiaca
# count         1196.000000  1196.000000         1196.000000
# mean           136.806856     1.367057            0.588629
# std             28.893056     1.525927            0.492288
# min             60.000000    -2.600000            0.000000
# 25%            116.000000     0.000000            0.000000
# 50%            138.000000     1.000000            1.000000
# 75%            159.000000     2.000000            1.000000
# max            202.000000     6.200000            1.000000

# %%
descripcion_data.describe_categorico()
# Out:
#         Sexo TipoDolorTorax ECGReposo AnginaDeEsfuerzo PendienteST
# count   1196           1196      1196             1196        1196
# unique     2              4         3                2           3
# top        M            ASY    Normal                N        Flat
# freq     863            576       640              697         548

# %%
tabla_completa.describe_complete()

# %%
tabla_completa.get_describe_complete()
# Out:
#                       tipo de dato tipo de variable  cardinalidad abs  \
# variable
# Edad                         int64         numerica                50
# Sexo                        object       categorica                 2
# TipoDolorTorax              object       categorica                 4
# PresionArterialReposo        int64         numerica               112
# Colesterol                   int64         numerica               316
# GlucosaEnAyunas              int64         numerica                 2
# ECGReposo                   object       categorica                 3
# FreqCardiacaMaxima           int64         numerica               134
# AnginaDeEsfuerzo            object       categorica                 2
# DescensoST                 float64         numerica                72
# PendienteST                 object       categorica                 3
# EnfermedadCardiaca           int64         numerica                 2
#
#                        cardinalidad %  distribucion  % missing  % Outliers  \
# variable
# Edad                         4.180602  No Gaussiana        0.0        0.00
# Sexo                         0.167224          None        0.0         NaN
# TipoDolorTorax               0.334448          None        0.0         NaN
# PresionArterialReposo        9.364548  No Gaussiana        0.0        3.43
# Colesterol                  26.421405  No Gaussiana        0.0       20.57
# GlucosaEnAyunas              0.167224  No Gaussiana        0.0       22.91
# ECGReposo                    0.250836          None        0.0         NaN
# FreqCardiacaMaxima          11.204013  No Gaussiana        0.0        0.00
# AnginaDeEsfuerzo             0.167224          None        0.0         NaN
# DescensoST                   6.020067  No Gaussiana        0.0        3.34
# PendienteST                  0.250836          None        0.0         NaN
# EnfermedadCardiaca           0.167224  No Gaussiana        0.0        0.00
#
#                              rango   moda  mediana       media  desv estandar  \
# variable
# Edad                      (28, 77)   54.0     54.0   53.341137      10.776964
# Sexo                          None    NaN      NaN         NaN            NaN
# TipoDolorTorax                None    NaN      NaN         NaN            NaN
# PresionArterialReposo     (0, 200)  120.0    130.0  134.709030      22.492932
# Colesterol                (0, 603)    0.0    233.0  230.504181     127.480572
# GlucosaEnAyunas             (0, 1)    0.0      0.0    0.229097       0.420428
# ECGReposo                     None    NaN      NaN         NaN            NaN
# FreqCardiacaMaxima       (60, 202)  150.0    138.0  136.806856      28.893056
# AnginaDeEsfuerzo              None    NaN      NaN         NaN            NaN
# DescensoST             (-2.6, 6.2)    0.0      1.0    1.367057       1.525927
# PendienteST                   None    NaN      NaN         NaN            NaN
# EnfermedadCardiaca          (0, 1)    1.0      1.0    0.588629       0.492288
#
#                            Q1      Q3  asimetria  curtosis  Valor estad.  \
# variable
# Edad                    46.00   61.00  -0.180064 -0.484127      0.988921
# Sexo                      NaN     NaN        NaN       NaN           NaN
# TipoDolorTorax            NaN     NaN        NaN       NaN           NaN
# PresionArterialReposo  120.00  146.25   0.481763  1.208164      0.961075
# Colesterol             182.75  291.00  -0.026715  0.267151      0.933320
# GlucosaEnAyunas          0.00    0.00   1.290861 -0.334240      0.519698
# ECGReposo                 NaN     NaN        NaN       NaN           NaN
# FreqCardiacaMaxima     116.00  159.00  -0.084418 -0.603523      0.991337
# AnginaDeEsfuerzo          NaN     NaN        NaN       NaN           NaN
# DescensoST               0.00    2.00   1.075968  0.525425      0.866547
# PendienteST               NaN     NaN        NaN       NaN           NaN
# EnfermedadCardiaca       0.00    1.00  -0.360672 -1.873051      0.625074
#
#                          Valor de P prueba normalidad tipo asimetria
# variable
# Edad                   7.354098e-08         No normal       negativa
# Sexo                            NaN              None           None
# TipoDolorTorax                  NaN              None           None
# PresionArterialReposo  2.422748e-17         No normal       positiva
# Colesterol             1.089876e-22         No normal       negativa
# GlucosaEnAyunas        5.977235e-49         No normal       negativa
# ECGReposo                       NaN              None           None
# FreqCardiacaMaxima     1.720561e-06         No normal       negativa
# AnginaDeEsfuerzo                NaN              None           None
# DescensoST             1.003658e-30         No normal       positiva
# PendienteST                     NaN              None           None
# EnfermedadCardiaca     4.416855e-45         No normal       negativa

# %% [markdown]
# ## Conclusion

# %% [markdown]
# El dataset inicial comprendió 1196 muestras y 12 features, con 'EnfermedadCardiaca' como target binario. Se realizó una verificación de la calidad de los datos, confirmando la ausencia de duplicados y valores nulos.
#
# Puntos clave a resaltar:
#
# * Tamaño del dataset: 1196 observaciones y 12 columnas.
# * Variable objetivo: 'EnfermedadCardiaca' (binaria: 1 = enfermedad, 0 = ausencia).
# * Calidad de los datos: Sin duplicados ni valores nulos.

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# # Limpieza de los datos

# %% [markdown]
# Se ha identificado una anomalía en la columna 'PresionArterialReposo': la presencia de valores mínimos iguales a cero, lo cual es fisiológicamente improbable. Para determinar la mejor estrategia de tratamiento de estos datos, se procederá a cuantificar la frecuencia de estas incidencias.

# %%
data[data['PresionArterialReposo'] == 0]
# Out:
#      Edad Sexo TipoDolorTorax  PresionArterialReposo  Colesterol  \
# 449    55    M            NAP                      0           0
#
#      GlucosaEnAyunas ECGReposo  FreqCardiacaMaxima AnginaDeEsfuerzo  \
# 449                0    Normal                 155                N
#
#      DescensoST PendienteST  EnfermedadCardiaca
# 449         1.5        Flat                   1

# %% [markdown]
# Tras la identificación de un único registro con un valor de cero en la columna 'PresionArterialReposo', se ha decidido eliminar dicha observación. Dado que se trata de un caso aislado, su eliminación no afectará significativamente la representatividad del conjunto de datos para el análisis.

# %%
data = data.loc[data['PresionArterialReposo'] != 0]

# %% [markdown]
# Vamos hacer la misma comprobacion en la columna Colesterol

# %%
data[data['Colesterol'] == 0].shape[0]
# Out:
# 171

# %%
# grouped_means = df.groupby(['Edad', 'Sexo'])['Colesterol'].transform('mean')
data['Colesterol'].replace(0, np.nan, inplace=True);
# Out:
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_14204\307842084.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Colesterol'].replace(0, np.nan, inplace=True);
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_14204\307842084.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Colesterol'].replace(0, np.nan, inplace=True);

# %%
# Creando las variables que almacenan los valores de la media para cada género
gender_means = data.groupby('Sexo')['Colesterol'].mean().round()

# %%
gender_means
# Out:
# Sexo
# F    289.0
# M    260.0
# Name: Colesterol, dtype: float64

# %%
data['Colesterol'] = data.apply(
    lambda row: gender_means[row['Sexo']] if pd.isna(row['Colesterol']) else row['Colesterol'], axis=1
)
# Out:
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_14204\4008567480.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Colesterol'] = data.apply(

# %%
data['Colesterol'].isna().value_counts()
# Out:
# Colesterol
# False    1195
# Name: count, dtype: int64

# %% [markdown]
# Al analizar la columna ``Colesterol``, observamos una cantidad considerable de valores cero, lo cual era inconsistente con la realidad biológica. Debido al elevado número de estos valores, la eliminación no fue una opción viable, ya que habría afectado la representatividad de los datos. Por lo tanto, procedimos a imputar los valores faltantes utilizando la media de la columna. Para asegurar una media no sesgada, primero convertimos los valores cero a ``NaN`` y luego calculamos la media excluyendo estos valores. Además, dado que los niveles de colesterol tendían a variar con la edad y el sexo, realizamos una imputación estratificada, agrupando los datos por estas dos variables. Este enfoque nos permitió obtener una estimación más precisa y realista de los valores de colesterol

# %% [markdown]
# ----------------------------------------

# %% [markdown]
# Guardar archivo procesado tras los tratamientos realizados en los datos

# %%
# Guardando archivo con las actualizaciones realizadas en los datos

data.to_csv("../data/processed/heart_disease_dataset_new.csv", index=False)

# %% [markdown]
# -----------------------------------
